# %% [markdown]
# <a href="https://colab.research.google.com/github/ach-67-HI/cs1q4_practicaltest/blob/main/cs1q4_practicaltest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Enter your name: ")
scores_to_enter = int(input("Enter the number of scores to enter: "))
scores = []

for i in range(scores_to_enter):
    score = int(input(f"Enter score {i + 1}: "))
    scores.append(score)

total_score = sum(scores)
average_score = total_score / scores_to_enter
print(f"The total score is: {total_score} ")
print(f"The average score is: {average_score}")

if average_score <= 75:
  print("FAILED")
else:
  print("PASSED")
# Out:
# Enter your name: hi
# Enter the number of scores to enter: 2
# Enter score 1: 90
# Enter score 2: 90
# The total score is: 180
# The average score is: 90.0
# PASSED
